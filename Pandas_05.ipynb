# %% [markdown]
# <a href="https://colab.research.google.com/github/Nelrau/pandas/blob/main/Pandas_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparando, Tratando e Mesclando DataFrames
#
# ## Objetivo
#
# Vamos modificar os IDs para os nomes dos produtos, dos clientes e das lojas, para nossas análises ficarem mais intuitivas futuramente. Para isso, vamos criar um data frame com todos os detalhes.
#
# - Usaremos o método merge para isso e, depois se quisermos, podemos pegar apenas as colunas que queremos do dataframe final.

# %% [markdown]
# ### Criando nossos dataframes

# %%
import pandas as pd

#às vezes precisaremos mudar o encoding. Possiveis valores para testar:
#encoding='latin1', encoding='ISO-8859-1', encoding='utf-8' ou então encoding='cp1252'
vendas_df = pd.read_csv(r'/content/Contoso - Vendas - 2017.csv', sep=';')
produtos_df = pd.read_csv(r'/content/Contoso - Cadastro Produtos.csv',delimiter=';', encoding='ISO-8859-1')
lojas_df = pd.read_csv(r'/content/Contoso - Lojas.csv', sep=';', encoding='iso-8859-1'.upper())
clientes_df = pd.read_csv(r'/content/Contoso - Clientes.csv', sep=';', encoding='iso-8859-1'.upper())
#usaremos o display para ver todos os dataframes
display(vendas_df)
# Out:
#        Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                    1    01/01/2017    02/01/2017         1     86.0
# 1                    2    01/01/2017    06/01/2017         5    308.0
# 2                    3    01/01/2017    01/01/2017         0    294.0
# 3                    4    01/01/2017    01/01/2017         0    251.0
# 4                    5    01/01/2017    07/01/2017         6     94.0
# ...                ...           ...           ...       ...      ...
# 20576            20577    09/01/2017    09/01/2017         0     95.0
# 20577            20578    09/01/2017    15/01/2017         6    137.0
# 20578            20579    09/01/2017    09/01/2017         0    152.0
# 20579            20580    09/01/2017    15/01/2017         6     10.0
# 20580            20581    09/01/2017    09/01/2017         0      NaN
#
#        ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0           981.0          2.0      6825.0                 9.0
# 1          1586.0          2.0     18469.0                 9.0
# 2          1444.0          5.0     19730.0                13.0
# 3          1468.0          5.0     29326.0                 6.0
# 4          1106.0          2.0     22617.0                 4.0
# ...           ...          ...         ...                 ...
# 20576      1439.0          2.0      2468.0                 9.0
# 20577       646.0          2.0     12045.0                 9.0
# 20578       681.0          2.0     14265.0                 9.0
# 20579       718.0          2.0     28071.0                 9.0
# 20580         NaN          NaN         NaN                 NaN
#
#        Quantidade Devolvida
# 0                       1.0
# 1                       1.0
# 2                       1.0
# 3                       1.0
# 4                       1.0
# ...                     ...
# 20576                   0.0
# 20577                   0.0
# 20578                   0.0
# 20579                   0.0
# 20580                   NaN
#
# [20581 rows x 10 columns]

# %%
clientes_df = clientes_df.drop(['Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1)
display(clientes_df)
# Out:
#        ÿID Cliente Primeiro Nome     Sobrenome                        E-mail  \
# 0                1        Garnet    Lanfranchi   glanfranchi0@mayoclinic.com
# 1                2       Lurette     Roseblade     lroseblade1@bigcartel.com
# 2                3       Glenden     Ishchenko     gishchenko2@moonfruit.com
# 3                4         Baron  Jedrzejewsky   bjedrzejewsky3@e-recht24.de
# 4                5        Sheree      Bredbury      sbredbury4@sitemeter.com
# ...            ...           ...           ...                           ...
# 29058        29059        Trevor       Coleman   trevor5@adventure-works.com
# 29059        29060        Dakota     Henderson   dakota4@adventure-works.com
# 29060        29061        Jaclyn        Sharma  jaclyn33@adventure-works.com
# 29061        29062         Louis        Becker   louis36@adventure-works.com
# 29062        29063          Spen           NaN                           NaN
#
#           Genero  Numero de Filhos Data de Nascimento
# 0       Feminino               2.0         12/05/1995
# 1       Feminino               2.0         30/06/1943
# 2      Masculino               5.0         09/04/1989
# 3      Masculino               4.0         17/11/1998
# 4       Feminino               5.0         08/09/1975
# ...          ...               ...                ...
# 29058  Masculino               2.0         07/03/1958
# 29059  Masculino               0.0         19/04/1950
# 29060  Masculino               3.0         04/06/1958
# 29061  Masculino               3.0         15/09/1997
# 29062        NaN               NaN                NaN
#
# [29063 rows x 7 columns]

# %%
clientes_df = clientes_df[['ÿID Cliente','E-mail']]
produtos_df = produtos_df[['ID Produto', 'ÿNome do Produto']]
lojas_df = lojas_df[['ÿID Loja', 'Nome da Loja']]
display(clientes_df, produtos_df,lojas_df)
# Out:
#        ÿID Cliente                        E-mail
# 0                1   glanfranchi0@mayoclinic.com
# 1                2     lroseblade1@bigcartel.com
# 2                3     gishchenko2@moonfruit.com
# 3                4   bjedrzejewsky3@e-recht24.de
# 4                5      sbredbury4@sitemeter.com
# ...            ...                           ...
# 29058        29059   trevor5@adventure-works.com
# 29059        29060   dakota4@adventure-works.com
# 29060        29061  jaclyn33@adventure-works.com
# 29061        29062   louis36@adventure-works.com
# 29062        29063                           NaN
#
# [29063 rows x 2 columns]
#       ID Produto                                 ÿNome do Produto
# 0            873            Contoso Wireless Laser Mouse E50 Grey
# 1            879    Contoso Optical Wheel OEM PS/2 Mouse E60 Grey
# 2            880   Contoso Optical Wheel OEM PS/2 Mouse E60 Black
# 3            881   Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 4            882  Contoso Optical Wheel OEM PS/2 Mouse E60 Silver
# ...          ...                                              ...
# 1685        1602        SV DVD 12-Inch Player Portable M400 Black
# 1686        1606        SV DVD 9-Inch Player Portable M300 Silver
# 1687        1607       SV DVD 12-Inch Player Portable M400 Silver
# 1688        1611         SV DVD 9-Inch Player Portable M300 White
# 1689        1612        SV DVD 12-Inch Player Portable M400 White
#
# [1690 rows x 2 columns]
#      ÿID Loja                         Nome da Loja
# 0           1           Loja Contoso Seattle No.1
# 1           2           Loja Contoso Seattle No.2
# 2           3              Loja Contoso Kennewick
# 3           4               Loja Contoso Bellevue
# 4           5                Loja Contoso Redmond
# ..        ...                                  ...
# 301       306          Loja Contoso Europe Online
# 302       307            Loja Contoso Asia Online
# 303       308  Loja Contoso North America Reseller
# 304       309         Loja Contoso Europe Reseller
# 305       310           Loja Contoso Asia Reseller
#
# [306 rows x 2 columns]

# %% [markdown]
# ### Vamos tirar as colunas inúteis do clientes_df ou pegar apenas as colunas que quisermos

# %%
clientes_df = clientes_df.rename(columns={'ÿID Cliente':'ID Cliente'})
lojas_df = lojas_df.rename(columns={'ÿID Loja':'ID Loja'})

# %% [raw]
# .drop([coluna1, coluna2, coluna3]) -> retira as colunas: coluna1, coluna2, coluna3

# %%
vendas_df = vendas_df.merge(produtos_df, on='ID Produto')
vendas_df = vendas_df.merge(clientes_df, on='ID Cliente')
vendas_df = vendas_df.merge(lojas_df, on='ID Loja')

display(vendas_df)
# Out:
#        Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                    1    01/01/2017    02/01/2017         1     86.0
# 1                  203    01/01/2017    08/01/2017         7     86.0
# 2                 4972    03/01/2017    05/01/2017         2     86.0
# 3                10031    05/01/2017    07/01/2017         2     86.0
# 4                 5265    03/01/2017    03/01/2017         0     86.0
# ...                ...           ...           ...       ...      ...
# 16725             1440    01/01/2017    01/01/2017         0     90.0
# 16726            18336    08/01/2017    08/01/2017         0    272.0
# 16727            20530    09/01/2017    15/01/2017         6     46.0
# 16728            18240    08/01/2017    13/01/2017         5    133.0
# 16729            12561    06/01/2017    09/01/2017         3    261.0
#
#        ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0           981.0          2.0      6825.0                 9.0
# 1           325.0          2.0     18086.0                 9.0
# 2          1610.0          2.0     14027.0                 9.0
# 3          1534.0          2.0     15236.0                 9.0
# 4          1509.0          2.0     19476.0                 9.0
# ...           ...          ...         ...                 ...
# 16725       372.0          2.0      7432.0                 9.0
# 16726       359.0          5.0     20863.0                13.0
# 16727       400.0          2.0     27767.0                 9.0
# 16728       366.0          2.0      2963.0                 9.0
# 16729       339.0          5.0     22948.0                13.0
#
#        Quantidade Devolvida  \
# 0                       1.0
# 1                       1.0
# 2                       0.0
# 3                       0.0
# 4                       1.0
# ...                     ...
# 16725                   1.0
# 16726                   0.0
# 16727                   0.0
# 16728                   0.0
# 16729                   0.0
#
#                                       ÿNome do Produto_x  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                                       ÿNome do Produto_y  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                                       ÿNome do Produto_x  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                                       ÿNome do Produto_y  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                             E-mail_x  \
# 0             rbrumfieldmy@ameblo.jp
# 1              tharrap2h@twitter.com
# 2               emaces@reference.com
# 3        lsine6m@cargocollective.com
# 4                dfortmandb@army.mil
# ...                              ...
# 16725     lshambrokec1@shinystat.com
# 16726          knuschao2@booking.com
# 16727  dominic16@adventure-works.com
# 16728         sbuttrumqr@state.tx.us
# 16729    sarah46@adventure-works.com
#
#                                         ÿNome do Produto  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                             E-mail_y                 Nome da Loja
# 0             rbrumfieldmy@ameblo.jp         Loja Contoso Austin
# 1              tharrap2h@twitter.com         Loja Contoso Austin
# 2               emaces@reference.com         Loja Contoso Austin
# 3        lsine6m@cargocollective.com         Loja Contoso Austin
# 4                dfortmandb@army.mil         Loja Contoso Austin
# ...                              ...                          ...
# 16725     lshambrokec1@shinystat.com         Loja Contoso Dallas
# 16726          knuschao2@booking.com        Loja Contoso Sapporo
# 16727  dominic16@adventure-works.com    Loja Contoso Fond du Lac
# 16728         sbuttrumqr@state.tx.us       Loja Contoso Paterson
# 16729    sarah46@adventure-works.com  Loja Contoso Damascus No.1
#
# [16730 rows x 18 columns]

# %% [markdown]
# ### Agora vamos juntar os dataframes para ter 1 único dataframe com tudo "bonito"

# %% [raw]
# novo_dataframe = dataframe1.merge(dataframe2, on='coluna')

# %% [markdown]
# - Obs: O merge precisa das colunas com o mesmo nome para funcionar. Se não tiver, você precisa alterar o nome da coluna com o .rename

# %% [raw]
# dataframe.rename({'coluna1': 'novo_coluna_1'})

# %%
#juntando os dataframes


#exibindo o dataframe final

# %%
#vamos renomear o e-mail para ficar claro que é do cliente
vendas_df = vendas_df.rename(columns={'Email':'Email do cliente'})

# %%
vendas_df
# Out:
#        Numero da Venda Data da Venda Data do Envio  ID Canal  ID Loja  \
# 0                    1    01/01/2017    02/01/2017         1     86.0
# 1                  203    01/01/2017    08/01/2017         7     86.0
# 2                 4972    03/01/2017    05/01/2017         2     86.0
# 3                10031    05/01/2017    07/01/2017         2     86.0
# 4                 5265    03/01/2017    03/01/2017         0     86.0
# ...                ...           ...           ...       ...      ...
# 16725             1440    01/01/2017    01/01/2017         0     90.0
# 16726            18336    08/01/2017    08/01/2017         0    272.0
# 16727            20530    09/01/2017    15/01/2017         6     46.0
# 16728            18240    08/01/2017    13/01/2017         5    133.0
# 16729            12561    06/01/2017    09/01/2017         3    261.0
#
#        ID Produto  ID Promocao  ID Cliente  Quantidade Vendida  \
# 0           981.0          2.0      6825.0                 9.0
# 1           325.0          2.0     18086.0                 9.0
# 2          1610.0          2.0     14027.0                 9.0
# 3          1534.0          2.0     15236.0                 9.0
# 4          1509.0          2.0     19476.0                 9.0
# ...           ...          ...         ...                 ...
# 16725       372.0          2.0      7432.0                 9.0
# 16726       359.0          5.0     20863.0                13.0
# 16727       400.0          2.0     27767.0                 9.0
# 16728       366.0          2.0      2963.0                 9.0
# 16729       339.0          5.0     22948.0                13.0
#
#        Quantidade Devolvida  \
# 0                       1.0
# 1                       1.0
# 2                       0.0
# 3                       0.0
# 4                       1.0
# ...                     ...
# 16725                   1.0
# 16726                   0.0
# 16727                   0.0
# 16728                   0.0
# 16729                   0.0
#
#                                       ÿNome do Produto_x  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                                       ÿNome do Produto_y  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                                       ÿNome do Produto_x  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                                       ÿNome do Produto_y  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                             E-mail_x  \
# 0             rbrumfieldmy@ameblo.jp
# 1              tharrap2h@twitter.com
# 2               emaces@reference.com
# 3        lsine6m@cargocollective.com
# 4                dfortmandb@army.mil
# ...                              ...
# 16725     lshambrokec1@shinystat.com
# 16726          knuschao2@booking.com
# 16727  dominic16@adventure-works.com
# 16728         sbuttrumqr@state.tx.us
# 16729    sarah46@adventure-works.com
#
#                                         ÿNome do Produto  \
# 0             A. Datum Advanced Digital Camera M300 Pink
# 1                         SV Car Video LCD7W M7081 Brown
# 2             SV DVD 15-Inch Player Portable L200 Silver
# 3         The Phone Company PDA Palm 4.7 inch L850 Black
# 4      The Phone Company Smart phones Unlocked Intern...
# ...                                                  ...
# 16725            Adventure Works Laptop15.4W M1548 White
# 16726                        Fabrikam Laptop12 M2002 Red
# 16727                        WWI Laptop15.4W M0156 White
# 16728            Adventure Works Laptop15.4W M1548 Black
# 16729                     Fabrikam Laptop17W M7080 Black
#
#                             E-mail_y                 Nome da Loja
# 0             rbrumfieldmy@ameblo.jp         Loja Contoso Austin
# 1              tharrap2h@twitter.com         Loja Contoso Austin
# 2               emaces@reference.com         Loja Contoso Austin
# 3        lsine6m@cargocollective.com         Loja Contoso Austin
# 4                dfortmandb@army.mil         Loja Contoso Austin
# ...                              ...                          ...
# 16725     lshambrokec1@shinystat.com         Loja Contoso Dallas
# 16726          knuschao2@booking.com        Loja Contoso Sapporo
# 16727  dominic16@adventure-works.com    Loja Contoso Fond du Lac
# 16728         sbuttrumqr@state.tx.us       Loja Contoso Paterson
# 16729    sarah46@adventure-works.com  Loja Contoso Damascus No.1
#
# [16730 rows x 18 columns]

# %%
# !pip install update pandas
# Out:
# Collecting update
#   Downloading update-0.0.1-py2.py3-none-any.whl (2.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting style==1.1.0 (from update)
#   Downloading style-1.1.0-py2.py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: style, update
# Successfully installed style-1.1.0 update-0.0.1

# %% [markdown]
# ### Agora podemos começar as análises
